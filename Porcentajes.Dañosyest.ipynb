# %%
#Porcentajes

#Total de eventos en el periodo de 1807 a 2007
evtot=721
daños=61
estallidos=248
#eventos 'ordinarios'
ordin=evtot-daños-estallidos
print(ordin)
# Out:
# 412

# %%
import matplotlib.pyplot as plt

eventos = [248, 61, 412]
nombres = ["Estallidos", "Daños", "Resto de eventos"]
colores = ["#FFD97D", "#EE6055", "#AAF683"]
desfase = (0, 0, 0.1)
plt.pie(eventos, labels=nombres, autopct="%0.1f %%", colors=colores, explode=desfase)
plt.axis("equal")
plt.show()
